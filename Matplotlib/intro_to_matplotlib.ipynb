# %% [markdown]
# ## Introduction to Matplotlib

# %%
#El símbolo '%' es para declarar un 'magic command', y el 
#magic 'matplotlib inline' incluira los gráficos dentro del
#notebook junto al código.
# %matplotlib inline      

#matplotlib.pyplot es una colección de comandos que hace
#trabajar parecido a MATLAB.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Crear plot (figure) en blanco
plt.plot()
# Out:
# []

# %%
#Crear plot (figure) en blanco sin que se vean los []
#usando ';' al final de la declaración.

#plt.plot();

#También para evitar los [] sirve:
plt.plot()
plt.show()

# %%
#Ejemplo de otro plot
plt.plot([1, 2, 3, 4]);

# %%
#Otro ejemplo rápido:
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
#Existen dos tipos de plotting: 
# pyplot API
# object_oriented API

# %%
#1st method - ADD_SUBPLOT

#Este método añade un conjunto de ejes en la figura pero 
#suponiendolo en una matríz de filas y columnas. Los plots
#se añadirían entonces a la posición asignada.

fig = plt.figure()       #creates a figure 
fig.add_subplot(131)     #adds some axes
plt.plot([1, 2, 3, 4])

#ax = fig.add_subplot() se puede declarar tal:
#ax = fig.add_subplot(nrows, ncols, index, **kwargs)
#ax = fig.add_subplot(111) que es lo mismo que
#ax = fig.add_subplot(1, 1, 1)  #es el default

# Es bueno jugar con los parámetros, se entiende mejor.

fig.add_subplot(232)
plt.plot([1, 3, 2, 6])
fig.add_subplot(336)
plt.plot([5, 2, 6, 1])
fig.add_subplot(447)     #Esta la sobrepuse a proposito
plt.plot([0, 5, 1, 7])

plt.show()

# %%
#2nd method - AXES

#Este método añade un conjunto de ejes en la figura y se
#mostrarán en las posiciones y tamaños que fijemos, aún si
#ya existen otros ejes en dichos parámetros.

fig = plt.figure()      #creates a figure
ax = fig.add_axes([1, 1, 0.5, 0.5])
ax.plot(x, y)

ax = fig.add_axes([1.6, 1, 0.5, 0.5])
ax.plot([1, 4, 2, 8])

ax = fig.add_axes([2.2, 0.5, 0.5, 0.5])
ax.plot([1, 4, 2, 8])

plt.show()

# %%
# 3rd method - SUBPLOTS (RECOMMENDED)

#Esta función crea una figura y varios axes (los que se 
#especifiquen. Por ejemplo si:

#fig, ax = plt.subplots(3, 2), esto crearía grid 3x2 de plots
#a los cuales podemos configurar por separado.

#ax contiene las referencias a cada axes. Si quisieramos 
#acceder a uno de los axes (ejemplo): 
#  ax[1, 0].plot(y)

#Por default, plt.subplots() es plt.subplots(1, 1).

fig, ax = plt.subplots()   #
ax.plot(x, [50, 100, 200, 250]);             #add some data

# %%
#Figure Object and Axes Objects

type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
# 0. Import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
#fig, ax = plt.subplots(figsize=(10, 10))     #width, height
fig, ax = plt.subplots(2,2, figsize=(10, 10))

# 3. Plot data
#ax.plot(x, y)
ax[1, 0].plot(x, [1, 15, 43, 51])
ax[1, 0].set_facecolor('pink')

# 4. Customize plot
ax[1, 0].set(title="Simple Plot", 
             xlabel="x-axis",
             ylabel="y-axis")

# 5. Save & show (save the whole figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Type of Plots (Basics)
#
# Scatter Plots, Bar Plots, Histogram and Subplots.

# %% [markdown]
# ### Making figures with NumPy Arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Crear data
x = np.linspace(0, 10, 100)   #Funcion rara
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a Line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use the same data to make Scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a bar plot from dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store",
      ylabel="Prices($)");

# %%
#Another bar plot but horizontal
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Make some data for Histograms and plot it
np.random.seed(seed=0)
x = np.random.randn(1000)     # Del standard normal distrib.
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for subplots

# %%
# Subplot option 1 (Defining axis)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10,5))

# Plot to each different axis
np.random.seed(seed=1)
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2 (Defining index)
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10,5))

# Plot to each different index
np.random.seed(seed=2)
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas DataFrames

# %%
import pandas as pd

# %%
#Make a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Ejemplo de PLot sobre una serie:

ts = pd.Series(np.random.randn(365),
               index = pd.date_range("31/10/2020",
                                      periods = 365))
#ts, ts.cumsum()
ts = ts.cumsum()
ts.plot()

# %%
#Quitando el signo "$" a los precios

car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', "")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Son string, hay que cambiarlo a int!

type(car_sales["Price"][0])
# Out:
# str

# %%
# Quitando los últimos dos ceros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("31/10/2020",
                                        periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-10-31
# 1   Honda    Red          87899      4   5000 2020-11-01
# 2  Toyota   Blue          32549      3   7000 2020-11-02
# 3     BMW  Black          11179      5  22000 2020-11-03
# 4  Nissan  White         213095      4   3500 2020-11-04
# 5  Toyota  Green          99213      4   4500 2020-11-05
# 6   Honda   Blue          45698      4   7500 2020-11-06
# 7   Honda   Blue          54738      4   7000 2020-11-07
# 8  Toyota  White          60000      4   6250 2020-11-08
# 9  Nissan  White          31600      4   9700 2020-11-09

# %%
#Es necesario evaluarlo como integers (números)
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-10-31         4000
# 1   Honda    Red          87899      4   5000 2020-11-01         9000
# 2  Toyota   Blue          32549      3   7000 2020-11-02        16000
# 3     BMW  Black          11179      5  22000 2020-11-03        38000
# 4  Nissan  White         213095      4   3500 2020-11-04        41500
# 5  Toyota  Green          99213      4   4500 2020-11-05        46000
# 6   Honda   Blue          45698      4   7500 2020-11-06        53500
# 7   Honda   Blue          54738      4   7000 2020-11-07        60500
# 8  Toyota  White          60000      4   6250 2020-11-08        66750
# 9  Nissan  White          31600      4   9700 2020-11-09        76450

# %%
# Plotting Total Sales (Line PLot)
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
# La columna Price lo hacemos integer
car_sales["Price"] = car_sales["Price"].astype(int)

# Scatter Plot con Price numérico
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# Que tal un bar plot?
x = np.random.rand(10, 4)

# Convertimos a DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.934198  0.008087  0.417956  0.235673
# 1  0.468223  0.468340  0.192729  0.576759
# 2  0.390432  0.935915  0.936115  0.382292
# 3  0.755424  0.622501  0.371869  0.262631
# 4  0.922636  0.189209  0.789751  0.754237
# 5  0.208229  0.372940  0.447044  0.500051
# 6  0.600264  0.349973  0.598316  0.437802
# 7  0.950233  0.692236  0.521006  0.563063
# 8  0.108850  0.275506  0.705800  0.984629
# 9  0.302896  0.990762  0.352219  0.453824

# %%
#Ambas maneras se puede declarar:
#df.plot(kind="bar");
df.plot.bar();

# %%
#Usando car_sales para el bar plot:
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
#Ahora usando histogramas:
#car_sales["Odometer (KM)"].plot(kind="hist");
car_sales["Odometer (KM)"].plot.hist();

#Cambiando los 'bins' (divisiones del histograma)
#car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
 # Ahora con otro dataset más grande (303x14)
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Creando un histograma de 'age'
heart_disease['age'].plot.hist(bins=50);

# %%
#Plotting a histogram on subplots from a Pandas DataFrame
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

#Sin embargo, sigue sin ser ideal, todos se miden casi con 
#la misma medida.

# %% [markdown]
# ### Which one should you use? (Pyplot vs Matplotlib OO Method)
#
# * When plotting something quickly, okay to use Pyplot Method.
# * When plotting something more advanced, use the OO Method.

# %%
#Ejemplo OO Method:

over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
#len(over_50)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot Method 
over_50.plot(kind='scatter', 
             x='age', 
             y='chol',
             c='target',
             figsize=(10, 6));

# %%
# OO Method mixed with Pyplot method
fix, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter', 
             x='age', 
             y='chol',
             c='target',
             ax=ax);

#ax.set_xlim([45, 80])

# %%
# OO Method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"], 
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax.axhline(over_50["chol"].mean(),
           linestyle='--')

# %%
# Subplot of chol, age and thalach:
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1,
                               figsize=(10, 10))

# AX0:

# Add data to ax0
scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'])

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol",
        xlabel="Age",
        ylabel="Cholesterol")
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle='--')

# AX1:

# Add data to ax1
scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle='--')

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
#plt.style.use('seaborn-whitegrid')
plt.style.use('seaborn')
#plt.style.use('tableau-colorblind10')
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
# Create some data
np.random.seed(seed=4)
x = np.random.randn(10, 4)
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
ax = df.plot(kind='bar')

# %%
#Customize our plot with the set() method
ax = df.plot(kind='bar')
#Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
       xlabel="Row Number",
       ylabel="Random Number");
#Make the legend always visible
ax.legend().set_visible(True)

# %%
# Retomando una de las lineas de código anterior para
# cambiar el estilo.

plt.style.use('seaborn-whitegrid')

# OO Method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"], 
                     c=over_50["target"],
                     cmap="winter")   #change colour scheme

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax.axhline(over_50["chol"].mean(),
           linestyle='--')

# %%
# Customizing the 'x' and 'y' axis

# Subplot of chol, age and thalach:
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1,
                               figsize=(10, 10))

# AX0:

# Add data to ax0
scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'],
                      cmap="summer")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
         ylabel="Cholesterol")
#Change the x axis limits
ax0.set_xlim([50, 80])
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle='--')

# AX1:

# Add data to ax1
scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap="plasma")

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate")
# Change ax1 axis limits
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle='--')

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");

# %%
# La manera más facil de guardar nuestros gráficos sería
# haciendo click derecho en la imagen y guardar.

# La otra manera es guardando la figura.
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
